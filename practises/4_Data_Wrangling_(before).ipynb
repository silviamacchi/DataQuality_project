# %% [markdown]
# # **4. DATA WRANGLING**

# %% [markdown]
# *Data wrangling* is the process of transforming or preparing datasets to ensure they are actionable for a set of analysis tasks.
#
# Goals of data wrangling:
# - to make data usable in order to be parsed and manipulated by analysis tools.
#
# - to ensure that data are responsive to the intended analyses, *i.e.,* that contain the necessary information at an acceptable level of description and correctness, to support successful modeling and decision-making.

# %% [markdown]
# Import libraries:

# %%
import pandas as pd

# %% [markdown]
# Import data:

# %%
USA = pd.read_csv("https://raw.githubusercontent.com/camillasancricca/DATADIQ/master/TECHUSA.csv")

# %%
USA.info() #(count non null values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   permalink       1460 non-null   object
#  1   company         1460 non-null   object
#  2   numEmps         567 non-null    float64
#  3   category        1436 non-null   object
#  4   city            1442 non-null   object
#  5   state           1460 non-null   object
#  6   fundedDate      1460 non-null   object
#  7   raisedAmt       1460 non-null   int64
#  8   raisedCurrency  1460 non-null   object
#  9   round           1460 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 114.2+ KB

# %% [markdown]
# 1. Column Renaiming:

# %%
#Change the name of Column "category" to "cat"
USA.rename(columns={'category':'cat'})
# USA = USA.rename(columns={'category':'cat'}) to actually change the dataset
# Out:
#           permalink        company  numEmps       cat        city state  \
# 0          lifelock       LifeLock      NaN       web       Tempe    AZ
# 1          lifelock       LifeLock      NaN       web       Tempe    AZ
# 2          lifelock       LifeLock      NaN       web       Tempe    AZ
# 3       mycityfaces    MyCityFaces      7.0       web  Scottsdale    AZ
# 4          flypaper       Flypaper      NaN       web     Phoenix    AZ
# ...             ...            ...      ...       ...         ...   ...
# 1455        trusera        Trusera     15.0       web     Seattle    WA
# 1456     alerts-com     Alerts.com      NaN       web    Bellevue    WA
# 1457          myrio          Myrio     75.0  software     Bothell    WA
# 1458  grid-networks  Grid Networks      NaN       web     Seattle    WA
# 1459  grid-networks  Grid Networks      NaN       web     Seattle    WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 0      1-May-07    6850000            USD             b
# 1      1-Oct-06    6000000            USD             a
# 2      1-Jan-08   25000000            USD             c
# 3      1-Jan-08      50000            USD          seed
# 4      1-Feb-08    3000000            USD             a
# ...         ...        ...            ...           ...
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b
#
# [1460 rows x 10 columns]

# %%
#Change the name of multiple columns: "category" to "cat" and fundedDate to FD
USA.rename({'category':'cat','fundedDate':'FD'})
# Out:
#           permalink        company  numEmps  category        city state  \
# 0          lifelock       LifeLock      NaN       web       Tempe    AZ
# 1          lifelock       LifeLock      NaN       web       Tempe    AZ
# 2          lifelock       LifeLock      NaN       web       Tempe    AZ
# 3       mycityfaces    MyCityFaces      7.0       web  Scottsdale    AZ
# 4          flypaper       Flypaper      NaN       web     Phoenix    AZ
# ...             ...            ...      ...       ...         ...   ...
# 1455        trusera        Trusera     15.0       web     Seattle    WA
# 1456     alerts-com     Alerts.com      NaN       web    Bellevue    WA
# 1457          myrio          Myrio     75.0  software     Bothell    WA
# 1458  grid-networks  Grid Networks      NaN       web     Seattle    WA
# 1459  grid-networks  Grid Networks      NaN       web     Seattle    WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 0      1-May-07    6850000            USD             b
# 1      1-Oct-06    6000000            USD             a
# 2      1-Jan-08   25000000            USD             c
# 3      1-Jan-08      50000            USD          seed
# 4      1-Feb-08    3000000            USD             a
# ...         ...        ...            ...           ...
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b
#
# [1460 rows x 10 columns]

# %% [markdown]
# 2. Sorting:

# %%
USA.sort_values(by='category',ascending=False)
# Out:
#                   permalink                company  numEmps category  \
# 0                  lifelock               LifeLock      NaN      web
# 962         screamingsports       Screaming Sports      NaN      web
# 972              feedburner             FeedBurner      NaN      web
# 971                    info                   Info      NaN      web
# 968             scribestorm            ScribeStorm     12.0      web
# ...                     ...                    ...      ...      ...
# 911    collective-intellect   Collective Intellect      NaN      NaN
# 1122    silkroad-technology    SilkRoad technology      NaN      NaN
# 1123    silkroad-technology    SilkRoad technology      NaN      NaN
# 1246  silicon-alley-insider  Silicon Alley Insider      NaN      NaN
# 1356                paxfire                Paxfire      NaN      NaN
#
#                city state fundedDate  raisedAmt raisedCurrency  round
# 0             Tempe    AZ   1-May-07    6850000            USD      b
# 962         Atlanta    GA   1-Jul-07    1250000            USD      a
# 972         Chicago    IL   1-Jun-04    1000000            USD      a
# 971         Chicago    IL   1-Nov-04    8400000            USD      a
# 968       Fairfield    IA  24-Apr-06     225000            USD  angel
# ...             ...   ...        ...        ...            ...    ...
# 911         Boulder    CO  15-Apr-08    6600000            USD      b
# 1122  Winston-Salem    NC  19-Feb-08   10000000            USD      b
# 1123  Winston-Salem    NC  15-May-08   54000000            USD      c
# 1246       New York    NY  16-Jul-08     900000            USD   seed
# 1356       Sterling    VA  22-May-05    2100000            USD      a
#
# [1460 rows x 10 columns]

# %% [markdown]
# 3. Column Filtering:

# %%
#Filter the data considering a specific selection predicate
USA_filtered = USA[USA['city']=='Mountain View']
USA_filtered
# Out:
#          permalink        company  numEmps  category           city state  \
# 34           plaxo          Plaxo     50.0       web  Mountain View    CA
# 35           plaxo          Plaxo     50.0       web  Mountain View    CA
# 36           plaxo          Plaxo     50.0       web  Mountain View    CA
# 37           plaxo          Plaxo     50.0       web  Mountain View    CA
# 68          google         Google  20000.0       web  Mountain View    CA
# ..             ...            ...      ...       ...            ...   ...
# 874  plastic-logic  Plastic Logic      NaN  hardware  Mountain View    CA
# 875  plastic-logic  Plastic Logic      NaN  hardware  Mountain View    CA
# 876  plastic-logic  Plastic Logic      NaN  hardware  Mountain View    CA
# 877  plastic-logic  Plastic Logic      NaN  hardware  Mountain View    CA
# 878  plastic-logic  Plastic Logic      NaN  hardware  Mountain View    CA
#
#     fundedDate  raisedAmt raisedCurrency round
# 34    1-Nov-02    3800000            USD     a
# 35    1-Jul-03    8500000            USD     b
# 36    1-Apr-04    7000000            USD     c
# 37    1-Feb-07    9000000            USD     d
# 68    1-Jun-99   25000000            USD     a
# ..         ...        ...            ...   ...
# 874  20-Apr-02   13700000            USD     a
# 875   5-Jan-05    8000000            USD     b
# 876  30-Nov-05   24000000            USD     c
# 877   6-Jan-07  100000000            USD     d
# 878   4-Aug-08   50000000            USD     e
#
# [89 rows x 10 columns]

# %% [markdown]
# 4. Dropping:

# %%
#Drop rows considering specific filtered data
USA_fff = USA.drop(USA[USA['city']=='Mountain View'].index)
USA_fff
# Out:
#           permalink        company  numEmps  category        city state  \
# 0          lifelock       LifeLock      NaN       web       Tempe    AZ
# 1          lifelock       LifeLock      NaN       web       Tempe    AZ
# 2          lifelock       LifeLock      NaN       web       Tempe    AZ
# 3       mycityfaces    MyCityFaces      7.0       web  Scottsdale    AZ
# 4          flypaper       Flypaper      NaN       web     Phoenix    AZ
# ...             ...            ...      ...       ...         ...   ...
# 1455        trusera        Trusera     15.0       web     Seattle    WA
# 1456     alerts-com     Alerts.com      NaN       web    Bellevue    WA
# 1457          myrio          Myrio     75.0  software     Bothell    WA
# 1458  grid-networks  Grid Networks      NaN       web     Seattle    WA
# 1459  grid-networks  Grid Networks      NaN       web     Seattle    WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 0      1-May-07    6850000            USD             b
# 1      1-Oct-06    6000000            USD             a
# 2      1-Jan-08   25000000            USD             c
# 3      1-Jan-08      50000            USD          seed
# 4      1-Feb-08    3000000            USD             a
# ...         ...        ...            ...           ...
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b
#
# [1371 rows x 10 columns]

# %% [markdown]
# 5. Standardization:
#
#   *Standardization* consists of reorganizazation of composed fields, data type checks, and replacement of alternative spellings with a single one. This type of reorganization has the purpose of making comparisons easier.

# %%
#Change a value (in this case we want to avoid abbreviations)
USA.loc[USA['state']== 'AZ','state'] = 'Arizona'
USA
# Out:
#           permalink        company  numEmps  category        city    state  \
# 0          lifelock       LifeLock      NaN       web       Tempe  Arizona
# 1          lifelock       LifeLock      NaN       web       Tempe  Arizona
# 2          lifelock       LifeLock      NaN       web       Tempe  Arizona
# 3       mycityfaces    MyCityFaces      7.0       web  Scottsdale  Arizona
# 4          flypaper       Flypaper      NaN       web     Phoenix  Arizona
# ...             ...            ...      ...       ...         ...      ...
# 1455        trusera        Trusera     15.0       web     Seattle       WA
# 1456     alerts-com     Alerts.com      NaN       web    Bellevue       WA
# 1457          myrio          Myrio     75.0  software     Bothell       WA
# 1458  grid-networks  Grid Networks      NaN       web     Seattle       WA
# 1459  grid-networks  Grid Networks      NaN       web     Seattle       WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 0      1-May-07    6850000            USD             b
# 1      1-Oct-06    6000000            USD             a
# 2      1-Jan-08   25000000            USD             c
# 3      1-Jan-08      50000            USD          seed
# 4      1-Feb-08    3000000            USD             a
# ...         ...        ...            ...           ...
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b
#
# [1460 rows x 10 columns]

# %% [markdown]
# 6. Column Splitting:

# %%
NBA = pd.read_csv("https://raw.githubusercontent.com/camillasancricca/DATADIQ/master/NBA.csv")

# %%
#Split a column into two
NBA_split_1 = NBA.Name.str.split(" ", n=1, expand=True)
NBA_split_1
# Out:
#            0        1
# 0      Avery  Bradley
# 1        Jae  Crowder
# 2       John  Holland
# 3       R.J.   Hunter
# 4      Jonas  Jerebko
# ..       ...      ...
# 442     Trey    Lyles
# 443  Shelvin     Mack
# 444     Raul     Neto
# 445    Tibor   Pleiss
# 446     Jeff   Withey
#
# [447 rows x 2 columns]

# %%
#Add two columns generated from the split function
NBA[['name','surname']] = NBA_split_1

# %%
#Drop the original column
NBA = NBA.drop('Name', axis=1)
NBA
# Out:
#                Team  Number Position   Age Height  Weight            College  \
# 0    Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 1    Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette
# 2    Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3    Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
# ..              ...     ...      ...   ...    ...     ...                ...
# 442       Utah Jazz    41.0       PF  20.0   6-10   234.0           Kentucky
# 443       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler
# 444       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN
# 445       Utah Jazz    21.0        C  26.0    7-3   256.0                NaN
# 446       Utah Jazz    24.0        C  26.0    7-0   231.0             Kansas
#
#         Salary     name  surname
# 0    7730337.0    Avery  Bradley
# 1    6796117.0      Jae  Crowder
# 2          NaN     John  Holland
# 3    1148640.0     R.J.   Hunter
# 4    5000000.0    Jonas  Jerebko
# ..         ...      ...      ...
# 442  2239800.0     Trey    Lyles
# 443  2433333.0  Shelvin     Mack
# 444   900000.0     Raul     Neto
# 445  2900000.0    Tibor   Pleiss
# 446   947276.0     Jeff   Withey
#
# [447 rows x 10 columns]

# %% [markdown]
# 7. Column Merging:

# %%
#The space is the default separator, but if the separator is different we have to explicit it
NBA['complete name'] = NBA['surname'].str.cat(NBA['name'], sep=', ')
NBA
# Out:
#                Team  Number Position   Age Height  Weight            College  \
# 0    Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 1    Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette
# 2    Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3    Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4    Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
# ..              ...     ...      ...   ...    ...     ...                ...
# 442       Utah Jazz    41.0       PF  20.0   6-10   234.0           Kentucky
# 443       Utah Jazz     8.0       PG  26.0    6-3   203.0             Butler
# 444       Utah Jazz    25.0       PG  24.0    6-1   179.0                NaN
# 445       Utah Jazz    21.0        C  26.0    7-3   256.0                NaN
# 446       Utah Jazz    24.0        C  26.0    7-0   231.0             Kansas
#
#         Salary     name  surname   complete name
# 0    7730337.0    Avery  Bradley  Bradley, Avery
# 1    6796117.0      Jae  Crowder    Crowder, Jae
# 2          NaN     John  Holland   Holland, John
# 3    1148640.0     R.J.   Hunter    Hunter, R.J.
# 4    5000000.0    Jonas  Jerebko  Jerebko, Jonas
# ..         ...      ...      ...             ...
# 442  2239800.0     Trey    Lyles     Lyles, Trey
# 443  2433333.0  Shelvin     Mack   Mack, Shelvin
# 444   900000.0     Raul     Neto      Neto, Raul
# 445  2900000.0    Tibor   Pleiss   Pleiss, Tibor
# 446   947276.0     Jeff   Withey    Withey, Jeff
#
# [447 rows x 11 columns]

# %%
#Create a new Dataframe of addresses
ADDR = pd.DataFrame({
    'Address': ['4860 Sunset Boulevard,San Francisco,California',
                '3055 Paradise Lane,Salt Lake City,Utah',
                '682 Main Street,Detroit,Michigan',
                '9001 Cascade Road,Kansas City,Missouri']
})

# %%
#We can split into more than 2 columns
#n defines the number of times to split in one tuple
ADDR_split = ADDR['Address'].str.split(',', n=2, expand=True)
ADDR_split
# Out:
#                        0               1           2
# 0  4860 Sunset Boulevard   San Francisco  California
# 1     3055 Paradise Lane  Salt Lake City        Utah
# 2        682 Main Street         Detroit    Michigan
# 3      9001 Cascade Road     Kansas City    Missouri

# %%
#Split a column and add new columns

# %%
#Drop the original column

# %% [markdown]
# 8. Dealing with Missing Data:
#
#   - drop missing values with ***dropna***
#   (axis --> "0": drops the rows with missing;
#   "1": drops column with missing)
#
#   - fill missing values with ***fillna***
#   (method --> "ffill": propagate last valid observation forward to next valid;
#   "bfill": use next valid observation to fill gap; axis (along which to fill missing values) --> "0": rows; "1": columns)

# %%
USA = pd.read_csv("https://raw.githubusercontent.com/camillasancricca/DATADIQ/master/TECHUSA.csv")

# %%
USA.dropna(axis=0)

# %%
USA.numEmps = USA.numEmps.fillna('unknown')
USA
# Out:
#           permalink        company  numEmps  category        city state  \
# 0          lifelock       LifeLock  unknown       web       Tempe    AZ
# 1          lifelock       LifeLock  unknown       web       Tempe    AZ
# 2          lifelock       LifeLock  unknown       web       Tempe    AZ
# 3       mycityfaces    MyCityFaces      7.0       web  Scottsdale    AZ
# 4          flypaper       Flypaper  unknown       web     Phoenix    AZ
# ...             ...            ...      ...       ...         ...   ...
# 1455        trusera        Trusera     15.0       web     Seattle    WA
# 1456     alerts-com     Alerts.com  unknown       web    Bellevue    WA
# 1457          myrio          Myrio     75.0  software     Bothell    WA
# 1458  grid-networks  Grid Networks  unknown       web     Seattle    WA
# 1459  grid-networks  Grid Networks  unknown       web     Seattle    WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 0      1-May-07    6850000            USD             b
# 1      1-Oct-06    6000000            USD             a
# 2      1-Jan-08   25000000            USD             c
# 3      1-Jan-08      50000            USD          seed
# 4      1-Feb-08    3000000            USD             a
# ...         ...        ...            ...           ...
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b
#
# [1460 rows x 10 columns]

# %%
USA.fillna(method = 'ffill') #(bfill it's the opposite)
# Out:
# /tmp/ipython-input-3411944467.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   USA.fillna(method = 'ffill')
#           permalink        company  numEmps  category        city state  \
# 0          lifelock       LifeLock  unknown       web       Tempe    AZ
# 1          lifelock       LifeLock  unknown       web       Tempe    AZ
# 2          lifelock       LifeLock  unknown       web       Tempe    AZ
# 3       mycityfaces    MyCityFaces      7.0       web  Scottsdale    AZ
# 4          flypaper       Flypaper  unknown       web     Phoenix    AZ
# ...             ...            ...      ...       ...         ...   ...
# 1455        trusera        Trusera     15.0       web     Seattle    WA
# 1456     alerts-com     Alerts.com  unknown       web    Bellevue    WA
# 1457          myrio          Myrio     75.0  software     Bothell    WA
# 1458  grid-networks  Grid Networks  unknown       web     Seattle    WA
# 1459  grid-networks  Grid Networks  unknown       web     Seattle    WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 0      1-May-07    6850000            USD             b
# 1      1-Oct-06    6000000            USD             a
# 2      1-Jan-08   25000000            USD             c
# 3      1-Jan-08      50000            USD          seed
# 4      1-Feb-08    3000000            USD             a
# ...         ...        ...            ...           ...
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b
#
# [1460 rows x 10 columns]

# %% [markdown]
# 9. Formatting values:

# %%
#methods to format values
df = pd.DataFrame(
    data={
        "Currency": {0: 111.23, 1: 321.23}
    }
)
format_mapping = {"Currency": "{:,.2f}"}

# %%
df = pd.DataFrame(
    data={
        "Int": {0: 23, 1: 3}
    }
)
format_mapping = {"Int": "{:,.0f}"}

# %%
df = pd.DataFrame(
    data={
        "Rate": {0: 0.03030, 1: 0.09840},
    }
)
format_mapping = {"Rate": "{:.2f}%"}

# %% [markdown]
# 10. Set columns names:

# %%
df = pd.DataFrame([(1,2,3), ('foo','bar','baz'), (4,5,6)])

# %%
df.columns = df.iloc[1] #localize rows based on index
df
# Out:
# 1  foo  bar  baz
# 0    1    2    3
# 1  foo  bar  baz
# 2    4    5    6

# %%
df.transpose()
# Out:
#      0    1  2
# 1
# foo  1  foo  4
# bar  2  bar  5
# baz  3  baz  6

# %% [markdown]
# 11. Transpose:

# %% [markdown]
# **Summary:**
#
# *Data Wrangling operations:*
# - DataFrame.info()
# - DataFrame.rename()
# - DataFrame.sort_values()
# - DataFrame.drop()
# - DataFrame.Name.str.split()
# - DataFrame.str.cat()
# - DataFrame.dropna()
# - DataFrame.fillna()
# - DataFrame.style.format()
# - DataFrame.iloc()
# - DataFrame.transpose()
