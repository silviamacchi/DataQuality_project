# %% [markdown]
# # **3. ASSOCIATION RULES MINING**

# %% [markdown]
# Finding frequent patterns and associations among sets of items in transaction databases, relational databases, or other information repositories.
#
# Given a set of transactions, find rules that will predict the occurrence of an item based on the occurrences of other items in a transaction.
#
#     An association rule is an implication of the form X → Y, where X and Y are itemsets.
#
# *Evaluation metrics*:
#
#       Support = fraction of transactions that contain both X and Y.
#       Confidence = how often items in Y appear in transactions that contain X.
#
# ***GOAL***
#
# Given a set of transactions T, the goal of association rule mining is to find all rules having
# 1. support >= minsup_threshold
#
#         Frequent Itemset = an itemset whose support is greater than or equal to the minsup_threshold.
#
# 2. confidence >= minconf_threshold.
#
# **Mining Association Rules** *Two step approach*:
#
#     1. Frequent Itemset Generation: Generate all itemsets whose support >= minsup (computationally expensive)
#     2. Rule Generation: Generate high confidence rules from frequent itemset

# %% [markdown]
# Import libraries:

# %%
# !git clone https://github.com/camillasancricca/DATADIQ.git
# Out:
# Cloning into 'DATADIQ'...
# remote: Enumerating objects: 238, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 238 (delta 44), reused 1 (delta 1), pack-reused 139 (from 1)
# Receiving objects: 100% (238/238), 11.34 MiB | 2.25 MiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
# !pip install mlxtend pyECLAT efficient-apriori plotly
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.12/dist-packages (0.23.4)
# Collecting pyECLAT
#   Downloading pyECLAT-1.0.2-py3-none-any.whl.metadata (4.0 kB)
# Collecting efficient-apriori
#   Downloading efficient_apriori-2.0.6-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from pyECLAT) (4.67.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Downloading pyECLAT-1.0.2-py3-none-any.whl (6.3 kB)
# Downloading efficient_apriori-2.0.6-py3-none-any.whl (14 kB)
# Installing collected packages: efficient-apriori, pyECLAT
# Successfully installed efficient-apriori-2.0.6 pyECLAT-1.0.2

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).

# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import plotly.express as px
from mlxtend.frequent_patterns import fpgrowth
from pyECLAT import ECLAT
from DATADIQ import eff_apriori
import plotly.offline as pyo
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).

# %% [markdown]
# ***1. FREQUENT ITEMSET GENERATION***

# %% [markdown]
# **APRIORI**
#
# ***Apriori principle***: If an itemset is frequent, then all of its subsets must also be frequent → supersets of not-frequent itemset can be pruned from the lattice.
#
# *Main steps*:
#
#       1. Start with itemsets containing just a single item (Individual items)
#       2. Determine the support for itemsets
#       3. Keep the itemsets that meet the minimum support threshold and remove itemsets that do not support minimum support
#       4. Use the itemsets that are kept and generate all the possible itemset combinations
#
#       *Repeat steps 3 and 4 until there are no more new itemsets*.

# %%
BASKET = pd.read_csv('https://raw.githubusercontent.com/camillasancricca/DATADIQ/master/MARKETBASKET.csv', header=None)
BASKET
# Out:
#                    0                  1              2                 3   \
# 0              shrimp            almonds        avocado    vegetables mix
# 1             burgers          meatballs           eggs               NaN
# 2             chutney                NaN            NaN               NaN
# 3              turkey            avocado            NaN               NaN
# 4       mineral water               milk     energy bar  whole wheat rice
# ...               ...                ...            ...               ...
# 996            shrimp         body spray      green tea               NaN
# 997   frozen smoothie                NaN            NaN               NaN
# 998     herb & pepper  frozen vegetables  mineral water           muffins
# 999            turkey           tomatoes      spaghetti              milk
# 1000    herb & pepper           red wine      spaghetti              eggs
#
#                     4                 5             6               7   \
# 0         green grapes  whole weat flour          yams  cottage cheese
# 1                  NaN               NaN           NaN             NaN
# 2                  NaN               NaN           NaN             NaN
# 3                  NaN               NaN           NaN             NaN
# 4            green tea               NaN           NaN             NaN
# ...                ...               ...           ...             ...
# 996                NaN               NaN           NaN             NaN
# 997                NaN               NaN           NaN             NaN
# 998            cereals               NaN           NaN             NaN
# 999              cider              eggs         honey            cake
# 1000  whole wheat rice         chocolate  french fries        escalope
#
#                 8             9               10            11     12     13  \
# 0     energy drink  tomato juice  low fat yogurt     green tea  honey  salad
# 1              NaN           NaN             NaN           NaN    NaN    NaN
# 2              NaN           NaN             NaN           NaN    NaN    NaN
# 3              NaN           NaN             NaN           NaN    NaN    NaN
# 4              NaN           NaN             NaN           NaN    NaN    NaN
# ...            ...           ...             ...           ...    ...    ...
# 996            NaN           NaN             NaN           NaN    NaN    NaN
# 997            NaN           NaN             NaN           NaN    NaN    NaN
# 998            NaN           NaN             NaN           NaN    NaN    NaN
# 999      green tea  french fries        brownies  tomato juice    NaN    NaN
# 1000       cookies           NaN             NaN           NaN    NaN    NaN
#
#                  14      15                 16               17       18  \
# 0     mineral water  salmon  antioxydant juice  frozen smoothie  spinach
# 1               NaN     NaN                NaN              NaN      NaN
# 2               NaN     NaN                NaN              NaN      NaN
# 3               NaN     NaN                NaN              NaN      NaN
# 4               NaN     NaN                NaN              NaN      NaN
# ...             ...     ...                ...              ...      ...
# 996             NaN     NaN                NaN              NaN      NaN
# 997             NaN     NaN                NaN              NaN      NaN
# 998             NaN     NaN                NaN              NaN      NaN
# 999             NaN     NaN                NaN              NaN      NaN
# 1000            NaN     NaN                NaN              NaN      NaN
#
#              19
# 0     olive oil
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 996         NaN
# 997         NaN
# 998         NaN
# 999         NaN
# 1000        NaN
#
# [1001 rows x 20 columns]

# %%
#Put all items of each transactions into a list
records = []
for i in range (0, len(BASKET)):
    records.append([str(BASKET.values[i,j]) for j in range(0, 20)])

# %%
#Initializing the transactionEncoder
TE = TransactionEncoder()
array = TE.fit(records).transform(records)
array
# Out:
# array([[False,  True,  True, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
#Building the data frame rows are logical and columns are the items have been purchased
transf_df = pd.DataFrame(array, columns=TE.columns_)
list(transf_df.columns)
# Out:
# [' asparagus',
#  'almonds',
#  'antioxydant juice',
#  'asparagus',
#  'avocado',
#  'babies food',
#  'bacon',
#  'barbecue sauce',
#  'black tea',
#  'blueberries',
#  'body spray',
#  'bramble',
#  'brownies',
#  'bug spray',
#  'burger sauce',
#  'burgers',
#  'butter',
#  'cake',
#  'candy bars',
#  'carrots',
#  'cauliflower',
#  'cereals',
#  'champagne',
#  'chicken',
#  'chili',
#  'chocolate',
#  'chocolate bread',
#  'chutney',
#  'cider',
#  'clothes accessories',
#  'cookies',
#  'cooking oil',
#  'corn',
#  'cottage cheese',
#  'cream',
#  'dessert wine',
#  'eggplant',
#  'eggs',
#  'energy bar',
#  'energy drink',
#  'escalope',
#  'extra dark chocolate',
#  'flax seed',
#  'french fries',
#  'french wine',
#  'fresh bread',
#  'fresh tuna',
#  'fromage blanc',
#  'frozen smoothie',
#  'frozen vegetables',
#  'gluten free bar',
#  'grated cheese',
#  'green beans',
#  'green grapes',
#  'green tea',
#  'ground beef',
#  'gums',
#  'ham',
#  'hand protein bar',
#  'herb & pepper',
#  'honey',
#  'hot dogs',
#  'ketchup',
#  'light cream',
#  'light mayo',
#  'low fat yogurt',
#  'magazines',
#  'mashed potato',
#  'mayonnaise',
#  'meatballs',
#  'melons',
#  'milk',
#  'mineral water',
#  'mint',
#  'mint green tea',
#  'muffins',
#  'mushroom cream sauce',
#  'nan',
#  'napkins',
#  'nonfat milk',
#  'oatmeal',
#  'oil',
#  'olive oil',
#  'pancakes',
#  'parmesan cheese',
#  'pasta',
#  'pepper',
#  'pet food',
#  'pickles',
#  'protein bar',
#  'red wine',
#  'rice',
#  'salad',
#  'salmon',
#  'salt',
#  'sandwich',
#  'shallot',
#  'shampoo',
#  'shrimp',
#  'soda',
#  'soup',
#  'spaghetti',
#  'sparkling water',
#  'spinach',
#  'strawberries',
#  'strong cheese',
#  'tea',
#  'tomato juice',
#  'tomato sauce',
#  'tomatoes',
#  'toothpaste',
#  'turkey',
#  'vegetables mix',
#  'water spray',
#  'white wine',
#  'whole weat flour',
#  'whole wheat pasta',
#  'whole wheat rice',
#  'yams',
#  'yogurt cake',
#  'zucchini']

# %%
#Drop NaN
basket = transf_df.drop({'nan'}, axis=1)
basket
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 996        False    False              False      False    False        False
# 997        False    False              False      False    False        False
# 998        False    False              False      False    False        False
# 999        False    False              False      False    False        False
# 1000       False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# 0     False           False      False        False  ...   False
# 1     False           False      False        False  ...   False
# 2     False           False      False        False  ...   False
# 3     False           False      False        False  ...    True
# 4     False           False      False        False  ...   False
# ...     ...             ...        ...          ...  ...     ...
# 996   False           False      False        False  ...   False
# 997   False           False      False        False  ...   False
# 998   False           False      False        False  ...   False
# 999   False           False      False        False  ...    True
# 1000  False           False      False        False  ...   False
#
#       vegetables mix  water spray  white wine  whole weat flour  \
# 0               True        False       False              True
# 1              False        False       False             False
# 2              False        False       False             False
# 3              False        False       False             False
# 4              False        False       False             False
# ...              ...          ...         ...               ...
# 996            False        False       False             False
# 997            False        False       False             False
# 998            False        False       False             False
# 999            False        False       False             False
# 1000           False        False       False             False
#
#       whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                 False             False   True        False     False
# 1                 False             False  False        False     False
# 2                 False             False  False        False     False
# 3                 False             False  False        False     False
# 4                 False              True  False        False     False
# ...                 ...               ...    ...          ...       ...
# 996               False             False  False        False     False
# 997               False             False  False        False     False
# 998               False             False  False        False     False
# 999               False             False  False        False     False
# 1000              False              True  False        False     False
#
# [1001 rows x 120 columns]

# %%
#Chose 0.03 minimum support (--> 0.03 ok because high variability on dataset)
a_rules = apriori(basket, min_support=0.03, use_colnames=True)
a_rules['length'] = a_rules['itemsets'].apply(lambda x: len(x))

# %%
#Frequent itemset
a_rules
# Out:
#      support                    itemsets  length
# 0   0.034965                   (avocado)       1
# 1   0.079920                   (burgers)       1
# 2   0.037962                    (butter)       1
# 3   0.075924                      (cake)       1
# 4   0.048951                 (champagne)       1
# ..       ...                         ...     ...
# 56  0.046953       (milk, mineral water)       2
# 57  0.044955           (milk, spaghetti)       2
# 58  0.034965  (olive oil, mineral water)       2
# 59  0.030969       (mineral water, soup)       2
# 60  0.057942  (mineral water, spaghetti)       2
#
# [61 rows x 3 columns]

# %% [markdown]
# ***2. RULES GENERATION***
#
# Given a frequent itemset L, find all non-empty subsets f ⊂ L such that f → L – f satisfies the minimum confidence requirement.

# %%
#Chose 0.05 minimum confidence (--> actually not reliable with this confidence, just for practise)
rules = association_rules(a_rules, metric="confidence", min_threshold=0.05)
rules
# Out:
#             antecedents          consequents  antecedent support  \
# 0             (burgers)               (eggs)            0.079920
# 1                (eggs)            (burgers)            0.207792
# 2           (chocolate)               (eggs)            0.188811
# 3                (eggs)          (chocolate)            0.207792
# 4        (french fries)          (chocolate)            0.159840
# 5           (chocolate)       (french fries)            0.188811
# 6           (chocolate)               (milk)            0.188811
# 7                (milk)          (chocolate)            0.135864
# 8           (chocolate)      (mineral water)            0.188811
# 9       (mineral water)          (chocolate)            0.244755
# 10          (chocolate)          (spaghetti)            0.188811
# 11          (spaghetti)          (chocolate)            0.185814
# 12       (french fries)               (eggs)            0.159840
# 13               (eggs)       (french fries)            0.207792
# 14               (eggs)               (milk)            0.207792
# 15               (milk)               (eggs)            0.135864
# 16               (eggs)      (mineral water)            0.207792
# 17      (mineral water)               (eggs)            0.244755
# 18               (eggs)          (spaghetti)            0.207792
# 19          (spaghetti)               (eggs)            0.185814
# 20               (eggs)             (turkey)            0.207792
# 21             (turkey)               (eggs)            0.078921
# 22       (french fries)          (spaghetti)            0.159840
# 23          (spaghetti)       (french fries)            0.185814
# 24      (mineral water)  (frozen vegetables)            0.244755
# 25  (frozen vegetables)      (mineral water)            0.094905
# 26          (spaghetti)  (frozen vegetables)            0.185814
# 27  (frozen vegetables)          (spaghetti)            0.094905
# 28          (green tea)      (mineral water)            0.140859
# 29      (mineral water)          (green tea)            0.244755
# 30        (ground beef)      (mineral water)            0.097902
# 31      (mineral water)        (ground beef)            0.244755
# 32        (ground beef)          (spaghetti)            0.097902
# 33          (spaghetti)        (ground beef)            0.185814
# 34               (milk)      (mineral water)            0.135864
# 35      (mineral water)               (milk)            0.244755
# 36               (milk)          (spaghetti)            0.135864
# 37          (spaghetti)               (milk)            0.185814
# 38          (olive oil)      (mineral water)            0.075924
# 39      (mineral water)          (olive oil)            0.244755
# 40      (mineral water)               (soup)            0.244755
# 41               (soup)      (mineral water)            0.072927
# 42      (mineral water)          (spaghetti)            0.244755
# 43          (spaghetti)      (mineral water)            0.185814
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.207792  0.033966    0.425000  2.045313               1.0
# 1             0.079920  0.033966    0.163462  2.045313               1.0
# 2             0.207792  0.042957    0.227513  1.094907               1.0
# 3             0.188811  0.042957    0.206731  1.094907               1.0
# 4             0.188811  0.037962    0.237500  1.257870               1.0
# 5             0.159840  0.037962    0.201058  1.257870               1.0
# 6             0.135864  0.045954    0.243386  1.791394               1.0
# 7             0.188811  0.045954    0.338235  1.791394               1.0
# 8             0.244755  0.058941    0.312169  1.275435               1.0
# 9             0.188811  0.058941    0.240816  1.275435               1.0
# 10            0.185814  0.050949    0.269841  1.452210               1.0
# 11            0.188811  0.050949    0.274194  1.452210               1.0
# 12            0.207792  0.040959    0.256250  1.233203               1.0
# 13            0.159840  0.040959    0.197115  1.233203               1.0
# 14            0.135864  0.034965    0.168269  1.238511               1.0
# 15            0.207792  0.034965    0.257353  1.238511               1.0
# 16            0.244755  0.059940    0.288462  1.178571               1.0
# 17            0.207792  0.059940    0.244898  1.178571               1.0
# 18            0.185814  0.038961    0.187500  1.009073               1.0
# 19            0.207792  0.038961    0.209677  1.009073               1.0
# 20            0.078921  0.034965    0.168269  2.132120               1.0
# 21            0.207792  0.034965    0.443038  2.132120               1.0
# 22            0.185814  0.032967    0.206250  1.109980               1.0
# 23            0.159840  0.032967    0.177419  1.109980               1.0
# 24            0.094905  0.034965    0.142857  1.505263               1.0
# 25            0.244755  0.034965    0.368421  1.505263               1.0
# 26            0.094905  0.031968    0.172043  1.812790               1.0
# 27            0.185814  0.031968    0.336842  1.812790               1.0
# 28            0.244755  0.033966    0.241135  0.985208               1.0
# 29            0.140859  0.033966    0.138776  0.985208               1.0
# 30            0.244755  0.036963    0.377551  1.542566               1.0
# 31            0.097902  0.036963    0.151020  1.542566               1.0
# 32            0.185814  0.034965    0.357143  1.922043               1.0
# 33            0.097902  0.034965    0.188172  1.922043               1.0
# 34            0.244755  0.046953    0.345588  1.411975               1.0
# 35            0.135864  0.046953    0.191837  1.411975               1.0
# 36            0.185814  0.044955    0.330882  1.780716               1.0
# 37            0.135864  0.044955    0.241935  1.780716               1.0
# 38            0.244755  0.034965    0.460526  1.881579               1.0
# 39            0.075924  0.034965    0.142857  1.881579               1.0
# 40            0.072927  0.030969    0.126531  1.735029               1.0
# 41            0.244755  0.030969    0.424658  1.735029               1.0
# 42            0.185814  0.057942    0.236735  1.274040               1.0
# 43            0.244755  0.057942    0.311828  1.274040               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.017359    1.377753       0.555470  0.133858   0.274180    0.294231
# 1   0.017359    1.099866       0.645130  0.133858   0.090798    0.294231
# 2   0.003724    1.025529       0.106856  0.121469   0.024894    0.217122
# 3   0.003724    1.022590       0.109417  0.121469   0.022091    0.217122
# 4   0.007782    1.063854       0.244008  0.122186   0.060022    0.219279
# 5   0.007782    1.051591       0.252722  0.122186   0.049060    0.219279
# 6   0.020301    1.142110       0.544603  0.164875   0.124427    0.290811
# 7   0.020301    1.225796       0.511234  0.164875   0.184204    0.290811
# 8   0.012729    1.098010       0.266219  0.157333   0.089261    0.276493
# 9   0.012729    1.068501       0.285938  0.157333   0.064110    0.276493
# 10  0.015865    1.115081       0.383874  0.157407   0.103204    0.272017
# 11  0.015865    1.117638       0.382461  0.157407   0.105256    0.272017
# 12  0.007746    1.065153       0.225080  0.125382   0.061168    0.226683
# 13  0.007746    1.046427       0.238705  0.125382   0.044367    0.226683
# 14  0.006734    1.038961       0.243091  0.113269   0.037500    0.212811
# 15  0.006734    1.066735       0.222857  0.113269   0.062560    0.212811
# 16  0.009082    1.061425       0.191257  0.152672   0.057870    0.266680
# 17  0.009082    1.049140       0.200617  0.152672   0.046838    0.266680
# 18  0.000350    1.002075       0.011349  0.109859   0.002071    0.198589
# 19  0.000350    1.002385       0.011043  0.109859   0.002380    0.198589
# 20  0.018566    1.107424       0.670258  0.138889   0.097004    0.305654
# 21  0.018566    1.422373       0.576480  0.138889   0.296950    0.305654
# 22  0.003266    1.025746       0.117933  0.105431   0.025100    0.191835
# 23  0.003266    1.021371       0.121695  0.105431   0.020924    0.191835
# 24  0.011737    1.055944       0.444444  0.114754   0.052980    0.255639
# 25  0.011737    1.195804       0.370861  0.114754   0.163743    0.255639
# 26  0.014333    1.093167       0.550690  0.128514   0.085226    0.254443
# 27  0.014333    1.227741       0.495378  0.128514   0.185496    0.254443
# 28 -0.000510    0.995229      -0.017176  0.096591  -0.004794    0.189955
# 29 -0.000510    0.997581      -0.019493  0.096591  -0.002425    0.189955
# 30  0.013001    1.213344       0.389902  0.120915   0.175831    0.264286
# 31  0.013001    1.062567       0.465716  0.120915   0.058883    0.264286
# 32  0.016773    1.266511       0.531783  0.140562   0.210429    0.272657
# 33  0.016773    1.111193       0.589202  0.140562   0.100067    0.272657
# 34  0.013700    1.154082       0.337646  0.140719   0.133510    0.268712
# 35  0.013700    1.069259       0.386328  0.140719   0.064773    0.268712
# 36  0.019710    1.216805       0.507360  0.162455   0.178176    0.286409
# 37  0.019710    1.139924       0.538487  0.162455   0.122748    0.286409
# 38  0.016382    1.399966       0.507027  0.122378   0.285697    0.301692
# 39  0.016382    1.078089       0.620370  0.122378   0.072432    0.301692
# 40  0.013120    1.061369       0.560932  0.108014   0.057820    0.275594
# 41  0.013120    1.312687       0.456966  0.108014   0.238204    0.275594
# 42  0.012463    1.066714       0.284802  0.155496   0.062542    0.274281
# 43  0.012463    1.097465       0.264184  0.155496   0.088809    0.274281

# %%
#Rules generation using the efficient-apriori library
ex = pd.read_csv('https://raw.githubusercontent.com/camillasancricca/DATADIQ/master/BRIDGES.csv')
eff_apriori.rules(ex,0.1,1) #returns also the index of the column
# Out:
# [{('ARCH', 12)} -> {('HIGHWAY', 4)}, {('ARCH', 12)} -> {('STEEL', 9)}, {('CANTILEV', 12)} -> {('STEEL', 9)}, {('IRON', 9)} -> {('THROUGH', 8)}, {('LONG', 10)} -> {('STEEL', 9)}, {('WOOD', 9)} -> {('S', 11)}, {('WOOD', 12)} -> {('S', 11)}, {('SUSPEN', 12)} -> {('THROUGH', 8)}, {('WOOD', 12)} -> {('WOOD', 9)}, {('WOOD', 9)} -> {('WOOD', 12)}, {('2', 6), ('LONG', 10)} -> {('STEEL', 9)}, {('M', 1), ('S', 11)} -> {('2', 6)}, {('2', 6), ('WOOD', 9)} -> {('N', 7)}, {('2', 6), ('WOOD', 12)} -> {('N', 7)}, {('2', 6), ('WOOD', 9)} -> {('S', 11)}, {('2', 6), ('WOOD', 12)} -> {('S', 11)}, {('2', 6), ('WOOD', 12)} -> {('WOOD', 9)}, {('2', 6), ('WOOD', 9)} -> {('WOOD', 12)}, {('4', 6), ('F', 11)} -> {('HIGHWAY', 4)}, {('4', 6), ('F', 11)} -> {('STEEL', 9)}, {('4', 6), ('MEDIUM', 10)} -> {('STEEL', 9)}, {('?', 5), ('F', 11)} -> {('G', 7)}, {('?', 5), ('STEEL', 9)} -> {('G', 7)}, {('A', 1), ('WOOD', 9)} -> {('S', 11)}, {('A', 1), ('WOOD', 12)} -> {('S', 11)}, {('A', 1), ('WOOD', 12)} -> {('WOOD', 9)}, {('A', 1), ('WOOD', 9)} -> {('WOOD', 12)}, {('ARCH', 12), ('G', 7)} -> {('HIGHWAY', 4)}, {('ARCH', 12), ('G', 7)} -> {('STEEL', 9)}, {('ARCH', 12), ('STEEL', 9)} -> {('HIGHWAY', 4)}, {('ARCH', 12), ('HIGHWAY', 4)} -> {('STEEL', 9)}, {('ARCH', 12)} -> {('HIGHWAY', 4), ('STEEL', 9)}, {('ARCH', 12), ('THROUGH', 8)} -> {('HIGHWAY', 4)}, {('ARCH', 12), ('THROUGH', 8)} -> {('STEEL', 9)}, {('DECK', 8), ('HIGHWAY', 4)} -> {('STEEL', 9)}, {('F', 11), ('MEDIUM', 10)} -> {('G', 7)}, {('F', 11), ('SIMPLE-T', 12)} -> {('G', 7)}, {('F', 11), ('LONG', 10)} -> {('STEEL', 9)}, {('F', 11), ('RR', 4)} -> {('STEEL', 9)}, {('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7)}, {('G', 7), ('LONG', 10)} -> {('STEEL', 9)}, {('G', 7), ('RR', 4)} -> {('STEEL', 9)}, {('S', 11), ('STEEL', 9)} -> {('G', 7)}, {('G', 7), ('S', 11)} -> {('THROUGH', 8)}, {('G', 7), ('S-F', 11)} -> {('STEEL', 9)}, {('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)}, {('HIGHWAY', 4), ('LONG', 10)} -> {('STEEL', 9)}, {('HIGHWAY', 4), ('S', 11)} -> {('THROUGH', 8)}, {('HIGHWAY', 4), ('WOOD', 9)} -> {('S', 11)}, {('HIGHWAY', 4), ('WOOD', 12)} -> {('S', 11)}, {('HIGHWAY', 4), ('WOOD', 9)} -> {('THROUGH', 8)}, {('HIGHWAY', 4), ('WOOD', 12)} -> {('THROUGH', 8)}, {('HIGHWAY', 4), ('WOOD', 12)} -> {('WOOD', 9)}, {('HIGHWAY', 4), ('WOOD', 9)} -> {('WOOD', 12)}, {('LONG', 10), ('M', 1)} -> {('STEEL', 9)}, {('LONG', 10), ('O', 1)} -> {('STEEL', 9)}, {('LONG', 10), ('O', 1)} -> {('THROUGH', 8)}, {('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)}, {('M', 1), ('S', 11)} -> {('THROUGH', 8)}, {('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12)}, {('MEDIUM', 10), ('RR', 4)} -> {('THROUGH', 8)}, {('S', 11), ('STEEL', 9)} -> {('MEDIUM', 10)}, {('MEDIUM', 10), ('S', 11)} -> {('THROUGH', 8)}, {('N', 7), ('WOOD', 9)} -> {('S', 11)}, {('N', 7), ('WOOD', 12)} -> {('S', 11)}, {('N', 7), ('WOOD', 12)} -> {('WOOD', 9)}, {('N', 7), ('WOOD', 9)} -> {('WOOD', 12)}, {('S', 11), ('STEEL', 9)} -> {('THROUGH', 8)}, {('THROUGH', 8), ('WOOD', 9)} -> {('S', 11)}, {('THROUGH', 8), ('WOOD', 12)} -> {('S', 11)}, {('WOOD', 9), ('WOOD', 12)} -> {('S', 11)}, {('S', 11), ('WOOD', 12)} -> {('WOOD', 9)}, {('S', 11), ('WOOD', 9)} -> {('WOOD', 12)}, {('WOOD', 12)} -> {('S', 11), ('WOOD', 9)}, {('WOOD', 9)} -> {('S', 11), ('WOOD', 12)}, {('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)}, {('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)}, {('2', 6), ('F', 11), ('HIGHWAY', 4)} -> {('G', 7)}, {('2', 6), ('F', 11), ('MEDIUM', 10)} -> {('G', 7)}, {('2', 6), ('F', 11), ('SIMPLE-T', 12)} -> {('G', 7)}, {('2', 6), ('F', 11), ('THROUGH', 8)} -> {('G', 7)}, {('2', 6), ('F', 11), ('HIGHWAY', 4)} -> {('THROUGH', 8)}, {('2', 6), ('F', 11), ('LONG', 10)} -> {('STEEL', 9)}, {('2', 6), ('F', 11), ('MEDIUM', 10)} -> {('THROUGH', 8)}, {('2', 6), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7)}, {('2', 6), ('G', 7), ('LONG', 10)} -> {('STEEL', 9)}, {('2', 6), ('LONG', 10), ('THROUGH', 8)} -> {('G', 7)}, {('2', 6), ('M', 1), ('STEEL', 9)} -> {('G', 7)}, {('2', 6), ('G', 7), ('RR', 4)}  ...
# [{('ARCH', 12)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12)} -> {('STEEL', 9)},
#  {('CANTILEV', 12)} -> {('STEEL', 9)},
#  {('IRON', 9)} -> {('THROUGH', 8)},
#  {('LONG', 10)} -> {('STEEL', 9)},
#  {('WOOD', 9)} -> {('S', 11)},
#  {('WOOD', 12)} -> {('S', 11)},
#  {('SUSPEN', 12)} -> {('THROUGH', 8)},
#  {('WOOD', 12)} -> {('WOOD', 9)},
#  {('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('LONG', 10)} -> {('STEEL', 9)},
#  {('M', 1), ('S', 11)} -> {('2', 6)},
#  {('2', 6), ('WOOD', 9)} -> {('N', 7)},
#  {('2', 6), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('WOOD', 9)} -> {('S', 11)},
#  {('2', 6), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('4', 6), ('F', 11)} -> {('HIGHWAY', 4)},
#  {('4', 6), ('F', 11)} -> {('STEEL', 9)},
#  {('4', 6), ('MEDIUM', 10)} -> {('STEEL', 9)},
#  {('?', 5), ('F', 11)} -> {('G', 7)},
#  {('?', 5), ('STEEL', 9)} -> {('G', 7)},
#  {('A', 1), ('WOOD', 9)} -> {('S', 11)},
#  {('A', 1), ('WOOD', 12)} -> {('S', 11)},
#  {('A', 1), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('A', 1), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('ARCH', 12), ('G', 7)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12), ('G', 7)} -> {('STEEL', 9)},
#  {('ARCH', 12), ('STEEL', 9)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12), ('HIGHWAY', 4)} -> {('STEEL', 9)},
#  {('ARCH', 12)} -> {('HIGHWAY', 4), ('STEEL', 9)},
#  {('ARCH', 12), ('THROUGH', 8)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('DECK', 8), ('HIGHWAY', 4)} -> {('STEEL', 9)},
#  {('F', 11), ('MEDIUM', 10)} -> {('G', 7)},
#  {('F', 11), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('F', 11), ('LONG', 10)} -> {('STEEL', 9)},
#  {('F', 11), ('RR', 4)} -> {('STEEL', 9)},
#  {('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('G', 7), ('LONG', 10)} -> {('STEEL', 9)},
#  {('G', 7), ('RR', 4)} -> {('STEEL', 9)},
#  {('S', 11), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('S', 11)} -> {('THROUGH', 8)},
#  {('G', 7), ('S-F', 11)} -> {('STEEL', 9)},
#  {('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('LONG', 10)} -> {('STEEL', 9)},
#  {('HIGHWAY', 4), ('S', 11)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('WOOD', 9)} -> {('S', 11)},
#  {('HIGHWAY', 4), ('WOOD', 12)} -> {('S', 11)},
#  {('HIGHWAY', 4), ('WOOD', 9)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('WOOD', 12)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('HIGHWAY', 4), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('LONG', 10), ('M', 1)} -> {('STEEL', 9)},
#  {('LONG', 10), ('O', 1)} -> {('STEEL', 9)},
#  {('LONG', 10), ('O', 1)} -> {('THROUGH', 8)},
#  {('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('M', 1), ('S', 11)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12)},
#  {('MEDIUM', 10), ('RR', 4)} -> {('THROUGH', 8)},
#  {('S', 11), ('STEEL', 9)} -> {('MEDIUM', 10)},
#  {('MEDIUM', 10), ('S', 11)} -> {('THROUGH', 8)},
#  {('N', 7), ('WOOD', 9)} -> {('S', 11)},
#  {('N', 7), ('WOOD', 12)} -> {('S', 11)},
#  {('N', 7), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('N', 7), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('S', 11), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('THROUGH', 8), ('WOOD', 9)} -> {('S', 11)},
#  {('THROUGH', 8), ('WOOD', 12)} -> {('S', 11)},
#  {('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('S', 11), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('S', 11), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('LONG', 10)} -> {('STEEL', 9)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10)} -> {('THROUGH', 8)},
#  {('2', 6), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('LONG', 10)} -> {('STEEL', 9)},
#  {('2', 6), ('LONG', 10), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('M', 1), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('RR', 4)} -> {('STEEL', 9)},
#  {('2', 6), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('N', 7), ('S', 11)} -> {('2', 6)},
#  {('2', 6), ('HIGHWAY', 4), ('S', 11)} -> {('THROUGH', 8)},
#  {('2', 6), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('M', 1), ('RR', 4)} -> {('SIMPLE-T', 12)},
#  {('M', 1), ('S', 11), ('THROUGH', 8)} -> {('2', 6)},
#  {('2', 6), ('M', 1), ('S', 11)} -> {('THROUGH', 8)},
#  {('M', 1), ('S', 11)} -> {('2', 6), ('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('S', 11)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('S', 11), ('WOOD', 9)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('WOOD', 9)} -> {('S', 11)},
#  {('2', 6), ('WOOD', 9)} -> {('N', 7), ('S', 11)},
#  {('2', 6), ('S', 11), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('WOOD', 12)} -> {('N', 7), ('S', 11)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9)} -> {('N', 7)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('WOOD', 9), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('N', 7), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('WOOD', 12)} -> {('N', 7), ('WOOD', 9)},
#  {('2', 6), ('WOOD', 9)} -> {('N', 7), ('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('S', 11), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('S', 11), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('2', 6), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('4', 6), ('F', 11), ('G', 7)} -> {('HIGHWAY', 4)},
#  {('4', 6), ('F', 11), ('G', 7)} -> {('STEEL', 9)},
#  {('4', 6), ('F', 11), ('STEEL', 9)} -> {('HIGHWAY', 4)},
#  {('4', 6), ('F', 11), ('HIGHWAY', 4)} -> {('STEEL', 9)},
#  {('4', 6), ('F', 11)} -> {('HIGHWAY', 4), ('STEEL', 9)},
#  {('4', 6), ('G', 7), ('MEDIUM', 10)} -> {('STEEL', 9)},
#  {('4', 6), ('HIGHWAY', 4), ('MEDIUM', 10)} -> {('STEEL', 9)},
#  {('?', 5), ('F', 11), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('?', 5), ('F', 11), ('THROUGH', 8)} -> {('G', 7)},
#  {('?', 5), ('F', 11), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('A', 1), ('F', 11), ('MEDIUM', 10)} -> {('G', 7)},
#  {('A', 1), ('F', 11), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('A', 1), ('F', 11), ('THROUGH', 8)} -> {('G', 7)},
#  {('A', 1), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('A', 1), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('A', 1), ('N', 7), ('WOOD', 9)} -> {('S', 11)},
#  {('A', 1), ('N', 7), ('WOOD', 12)} -> {('S', 11)},
#  {('A', 1), ('N', 7), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('A', 1), ('N', 7), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('A', 1), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11)},
#  {('A', 1), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11)},
#  {('A', 1), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('A', 1), ('S', 11), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('A', 1), ('S', 11), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('A', 1), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('A', 1), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('A', 1), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('A', 1), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('ARCH', 12), ('G', 7), ('STEEL', 9)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12), ('G', 7), ('HIGHWAY', 4)} -> {('STEEL', 9)},
#  {('ARCH', 12), ('G', 7)} -> {('HIGHWAY', 4), ('STEEL', 9)},
#  {('ARCH', 12), ('G', 7), ('THROUGH', 8)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12), ('G', 7), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('ARCH', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12), ('HIGHWAY', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('ARCH', 12), ('THROUGH', 8)} -> {('HIGHWAY', 4), ('STEEL', 9)},
#  {('F', 11), ('HIGHWAY', 4), ('MEDIUM', 10)} -> {('G', 7)},
#  {('F', 11), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('G', 7), ('LONG', 10), ('M', 1)} -> {('F', 11)},
#  {('F', 11), ('G', 7), ('LONG', 10)} -> {('STEEL', 9)},
#  {('F', 11), ('M', 1), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('F', 11), ('MEDIUM', 10), ('STEEL', 9)} -> {('G', 7)},
#  {('F', 11), ('MEDIUM', 10), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('F', 11), ('G', 7), ('RR', 4)} -> {('STEEL', 9)},
#  {('F', 11), ('RR', 4), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('F', 11), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('HIGHWAY', 4), ('LONG', 10)} -> {('STEEL', 9)},
#  {('F', 11), ('LONG', 10), ('M', 1)} -> {('STEEL', 9)},
#  {('LONG', 10), ('M', 1), ('THROUGH', 8)} -> {('F', 11)},
#  {('F', 11), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('F', 11), ('M', 1), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('F', 11), ('O', 1), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9)},
#  {('F', 11), ('RR', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('G', 7), ('HIGHWAY', 4), ('LONG', 10)} -> {('STEEL', 9)},
#  {('HIGHWAY', 4), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('LONG', 10), ('M', 1)} -> {('STEEL', 9)},
#  {('G', 7), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('M', 1), ('RR', 4), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('M', 1), ('RR', 4)} -> {('STEEL', 9)},
#  {('M', 1), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('STEEL', 9)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('S', 11), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('S', 11), ('STEEL', 9)} -> {('MEDIUM', 10)},
#  {('G', 7), ('MEDIUM', 10), ('S', 11)} -> {('STEEL', 9)},
#  {('S', 11), ('STEEL', 9)} -> {('G', 7), ('MEDIUM', 10)},
#  {('G', 7), ('MEDIUM', 10), ('S', 11)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9)},
#  {('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('RR', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('S', 11), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('S', 11), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('S', 11), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('LONG', 10), ('M', 1)} -> {('STEEL', 9)},
#  {('HIGHWAY', 4), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('HIGHWAY', 4), ('N', 7), ('S', 11)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11)},
#  {('HIGHWAY', 4), ('S', 11), ('WOOD', 9)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('WOOD', 9)} -> {('S', 11), ('THROUGH', 8)},
#  {('HIGHWAY', 4), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11)},
#  {('HIGHWAY', 4), ('S', 11), ('WOOD', 12)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('WOOD', 12)} -> {('S', 11), ('THROUGH', 8)},
#  {('HIGHWAY', 4), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('HIGHWAY', 4), ('S', 11), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('HIGHWAY', 4), ('S', 11), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('HIGHWAY', 4), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('HIGHWAY', 4), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('HIGHWAY', 4), ('WOOD', 9), ('WOOD', 12)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('HIGHWAY', 4), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('HIGHWAY', 4), ('WOOD', 12)} -> {('THROUGH', 8), ('WOOD', 9)},
#  {('HIGHWAY', 4), ('WOOD', 9)} -> {('THROUGH', 8), ('WOOD', 12)},
#  {('LONG', 10), ('M', 1), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('LONG', 10), ('O', 1), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('LONG', 10), ('O', 1), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('LONG', 10), ('O', 1)} -> {('STEEL', 9), ('THROUGH', 8)},
#  {('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12)},
#  {('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('S', 11), ('STEEL', 9), ('THROUGH', 8)} -> {('MEDIUM', 10)},
#  {('MEDIUM', 10), ('S', 11), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('S', 11), ('STEEL', 9)} -> {('MEDIUM', 10), ('THROUGH', 8)},
#  {('N', 7), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11)},
#  {('N', 7), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11)},
#  {('N', 7), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('N', 7), ('S', 11), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('N', 7), ('S', 11), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('N', 7), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('N', 7), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('N', 7), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('N', 7), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('THROUGH', 8), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('THROUGH', 8), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('2', 6), ('A', 1), ('G', 7), ('MEDIUM', 10)} -> {('THROUGH', 8)},
#  {('2', 6), ('A', 1), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('A', 1), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('G', 7), ('HIGHWAY', 4)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('G', 7), ('LONG', 10)} -> {('STEEL', 9)},
#  {('2', 6), ('F', 11), ('LONG', 10), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('G', 7), ('MEDIUM', 10)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('HIGHWAY', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('HIGHWAY', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('LONG', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('LONG', 10), ('THROUGH', 8)} -> {('G', 7), ('STEEL', 9)},
#  {('2', 6), ('M', 1), ('MEDIUM', 10), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('M', 1), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('M', 1), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('STEEL', 9)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9)},
#  {('2', 6), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('RR', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('N', 7), ('S', 11), ('THROUGH', 8)} -> {('2', 6)},
#  {('2', 6), ('HIGHWAY', 4), ('N', 7), ('S', 11)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('N', 7), ('S', 11)} -> {('2', 6), ('THROUGH', 8)},
#  {('2', 6), ('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9)} -> {('N', 7), ('S', 11)},
#  {('2', 6), ('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 12)} -> {('N', 7), ('S', 11)},
#  {('2', 6), ('S', 11), ('WOOD', 9), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('N', 7), ('S', 11), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('N', 7), ('S', 11), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('WOOD', 9), ('WOOD', 12)} -> {('N', 7), ('S', 11)},
#  {('2', 6), ('S', 11), ('WOOD', 12)} -> {('N', 7), ('WOOD', 9)},
#  {('2', 6), ('S', 11), ('WOOD', 9)} -> {('N', 7), ('WOOD', 12)},
#  {('2', 6), ('N', 7), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('2', 6), ('N', 7), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('2', 6), ('WOOD', 12)} -> {('N', 7), ('S', 11), ('WOOD', 9)},
#  {('2', 6), ('WOOD', 9)} -> {('N', 7), ('S', 11), ('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('N', 7), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 12)} -> {('N', 7), ('WOOD', 9)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9)} -> {('N', 7), ('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('4', 6), ('F', 11), ('G', 7), ('STEEL', 9)} -> {('HIGHWAY', 4)},
#  {('4', 6), ('F', 11), ('G', 7), ('HIGHWAY', 4)} -> {('STEEL', 9)},
#  {('4', 6), ('F', 11), ('G', 7)} -> {('HIGHWAY', 4), ('STEEL', 9)},
#  {('?', 5), ('G', 7), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('F', 11)},
#  {('?', 5), ('F', 11), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('?', 5), ('F', 11), ('G', 7), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('?', 5), ('F', 11), ('SIMPLE-T', 12)} -> {('G', 7), ('THROUGH', 8)},
#  {('A', 1), ('F', 11), ('MEDIUM', 10), ('STEEL', 9)} -> {('G', 7)},
#  {('A', 1), ('F', 11), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('A', 1), ('HIGHWAY', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('A', 1), ('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('A', 1), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('A', 1), ('N', 7), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('A', 1), ('N', 7), ('S', 11), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('A', 1), ('N', 7), ('S', 11), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('A', 1), ('N', 7), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('A', 1), ('N', 7), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('A', 1), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('A', 1), ('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('A', 1), ('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('A', 1), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('A', 1), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('ARCH', 12), ('G', 7), ('STEEL', 9), ('THROUGH', 8)} -> {('HIGHWAY', 4)},
#  {('ARCH', 12), ('G', 7), ('HIGHWAY', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('ARCH', 12), ('G', 7), ('THROUGH', 8)} -> {('HIGHWAY', 4), ('STEEL', 9)},
#  {('F', 11), ('G', 7), ('HIGHWAY', 4), ('LONG', 10)} -> {('STEEL', 9)},
#  {('F', 11), ('HIGHWAY', 4), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('G', 7)},
#  {('F', 11), ('HIGHWAY', 4), ('MEDIUM', 10), ('STEEL', 9)} -> {('G', 7)},
#  {('F', 11), ('HIGHWAY', 4), ('MEDIUM', 10), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('HIGHWAY', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('F', 11), ('HIGHWAY', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('LONG', 10), ('M', 1), ('STEEL', 9)} -> {('F', 11)},
#  {('F', 11), ('G', 7), ('LONG', 10), ('M', 1)} -> {('STEEL', 9)},
#  {('G', 7), ('LONG', 10), ('M', 1)} -> {('F', 11), ('STEEL', 9)},
#  {('F', 11), ('G', 7), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('F', 11), ('M', 1), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('G', 7), ('M', 1), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('F', 11), ('M', 1), ('SIMPLE-T', 12)} -> {('G', 7), ('THROUGH', 8)},
#  {('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('F', 11), ('G', 7), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12)} -> {('G', 7), ('STEEL', 9)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('G', 7), ('RR', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('F', 11), ('RR', 4), ('THROUGH', 8)} -> {('G', 7), ('STEEL', 9)},
#  {('F', 11), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('HIGHWAY', 4), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('LONG', 10), ('M', 1), ('STEEL', 9), ('THROUGH', 8)} -> {('F', 11)},
#  {('F', 11), ('LONG', 10), ('M', 1), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('LONG', 10), ('M', 1), ('THROUGH', 8)} -> {('F', 11), ('STEEL', 9)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('G', 7), ('HIGHWAY', 4), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('HIGHWAY', 4), ('MEDIUM', 10), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('HIGHWAY', 4), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('M', 1), ('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('M', 1), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('M', 1), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9)},
#  {('M', 1), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('M', 1), ('RR', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('M', 1), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7), ('SIMPLE-T', 12)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('STEEL', 9)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('STEEL', 9), ('THROUGH', 8)},
#  {('MEDIUM', 10), ('S', 11), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('S', 11), ('STEEL', 9), ('THROUGH', 8)} -> {('MEDIUM', 10)},
#  {('G', 7), ('MEDIUM', 10), ('S', 11), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('G', 7), ('MEDIUM', 10), ('S', 11), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('S', 11), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7), ('MEDIUM', 10)},
#  {('MEDIUM', 10), ('S', 11), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('G', 7), ('S', 11), ('STEEL', 9)} -> {('MEDIUM', 10), ('THROUGH', 8)},
#  {('G', 7), ('MEDIUM', 10), ('S', 11)} -> {('STEEL', 9), ('THROUGH', 8)},
#  {('S', 11), ('STEEL', 9)} -> {('G', 7), ('MEDIUM', 10), ('THROUGH', 8)},
#  {('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('HIGHWAY', 4), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('HIGHWAY', 4), ('S', 11), ('WOOD', 9), ('WOOD', 12)} -> {('THROUGH', 8)},
#  {('HIGHWAY', 4), ('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('HIGHWAY', 4), ('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('HIGHWAY', 4), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11), ('THROUGH', 8)},
#  {('HIGHWAY', 4), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('HIGHWAY', 4), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('HIGHWAY', 4), ('S', 11), ('WOOD', 12)} -> {('THROUGH', 8), ('WOOD', 9)},
#  {('HIGHWAY', 4), ('S', 11), ('WOOD', 9)} -> {('THROUGH', 8), ('WOOD', 12)},
#  {('HIGHWAY', 4), ('WOOD', 12)} -> {('S', 11), ('THROUGH', 8), ('WOOD', 9)},
#  {('HIGHWAY', 4), ('WOOD', 9)} -> {('S', 11), ('THROUGH', 8), ('WOOD', 12)},
#  {('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('N', 7), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('N', 7), ('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('N', 7), ('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('N', 7), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('N', 7), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('G', 7), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('SIMPLE-T', 12)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('G', 7), ('HIGHWAY', 4), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('HIGHWAY', 4), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('LONG', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('G', 7), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('F', 11), ('LONG', 10), ('THROUGH', 8)} -> {('G', 7), ('STEEL', 9)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('F', 11), ('G', 7), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('F', 11), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('M', 1), ('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('M', 1), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7), ('SIMPLE-T', 12)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('STEEL', 9)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('THROUGH', 8)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('STEEL', 9), ('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('2', 6), ('S', 11), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('N', 7)},
#  {('2', 6), ('N', 7), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('S', 11)},
#  {('2', 6), ('N', 7), ('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('WOOD', 9)},
#  {('2', 6), ('N', 7), ('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9), ('WOOD', 12)} -> {('N', 7), ('S', 11)},
#  {('2', 6), ('S', 11), ('THROUGH', 8), ('WOOD', 12)} -> {('N', 7), ('WOOD', 9)},
#  {('2', 6), ('S', 11), ('THROUGH', 8), ('WOOD', 9)} -> {('N', 7), ('WOOD', 12)},
#  {('2', 6), ('N', 7), ('THROUGH', 8), ('WOOD', 12)} -> {('S', 11), ('WOOD', 9)},
#  {('2', 6), ('N', 7), ('THROUGH', 8), ('WOOD', 9)} -> {('S', 11), ('WOOD', 12)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 12)} -> {('N', 7), ('S', 11), ('WOOD', 9)},
#  {('2', 6), ('THROUGH', 8), ('WOOD', 9)} -> {('N', 7), ('S', 11), ('WOOD', 12)},
#  {('A', 1), ('HIGHWAY', 4), ('MEDIUM', 10), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('G', 7), ('HIGHWAY', 4), ('LONG', 10), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('F', 11), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('F', 11), ('G', 7), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('F', 11), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('G', 7), ('STEEL', 9)},
#  {('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('M', 1), ('MEDIUM', 10), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('M', 1), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('M', 1), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7), ('SIMPLE-T', 12)},
#  {('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('SIMPLE-T', 12), ('STEEL', 9)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9), ('THROUGH', 8)},
#  {('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7), ('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('SIMPLE-T', 12)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('THROUGH', 8)} -> {('STEEL', 9)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9), ('THROUGH', 8)} -> {('G', 7), ('SIMPLE-T', 12)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12), ('STEEL', 9)} -> {('G', 7), ('THROUGH', 8)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('THROUGH', 8)} -> {('SIMPLE-T', 12), ('STEEL', 9)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4), ('SIMPLE-T', 12)} -> {('STEEL', 9), ('THROUGH', 8)},
#  {('2', 6), ('MEDIUM', 10), ('RR', 4), ('STEEL', 9)} -> {('G', 7), ('SIMPLE-T', 12), ('THROUGH', 8)},
#  {('2', 6), ('G', 7), ('MEDIUM', 10), ('RR', 4)} -> {('SIMPLE-T', 12), ('STEEL', 9), ('THROUGH', 8)}]

# %% [markdown]
# **ECLAT ALGORITHM**
#
# Leverages the tidsets directly for support computation.
#
# The support of a candidate itemset can be computed by intersecting the tidsets of suitably chosen subsets.
#
# *Main steps*:
#
#     1. Convert data into the vertical format
#     2. Set up the minimum support value
#     3. Esclude all items that appeared in number_of_transactions < minimum support value
#     4. Use the itemsets that are kept and generate all the possible itemset combinations
#
#     *Repeat steps 3 and 4 as many times as needed to analyze itemsets of the required length.*

# %%
#Loading transactions DataFrame to ECLAT class
eclat = ECLAT(data=BASKET)

# %%
#Count items in each row
items_per_transaction = eclat.df_bin.astype(int).sum(axis=1)
items_per_transaction
# Out:
# 0       20
# 1        3
# 2        1
# 3        2
# 4        5
#         ..
# 996      3
# 997      1
# 998      5
# 999     12
# 1000     9
# Length: 1001, dtype: int64

# %%
#The item shoud appear at least at 3% of transactions
min_support = 0.03
#Start from transactions containing at least 2 items (--> with just 1 not useful)
min_combination = 2
#up to 2 items per transaction
max_combination = 2

rule_indices, rule_supports = eclat.fit(min_support=min_support,
                                                 min_combination=min_combination,
                                                 max_combination=max_combination,
                                                 separator=' & ',
                                                 verbose=True)
# Out:
# Combination 2 by 2
# 741it [00:15, 48.36it/s]

# %%
#(--> to put it into a dataframe format)
result = pd.DataFrame(rule_supports.items(),columns=['Item', 'Support'])
result.sort_values(by=['Support'], ascending=False)
#(then should be filtered based on confidence)
# Out:
#                                  Item   Support
# 7                mineral water & eggs  0.059940
# 0           chocolate & mineral water  0.058941
# 11          mineral water & spaghetti  0.057942
# 4               chocolate & spaghetti  0.050949
# 8                mineral water & milk  0.046953
# 3                    chocolate & milk  0.045954
# 20                   milk & spaghetti  0.044955
# 2                    chocolate & eggs  0.042957
# 14                french fries & eggs  0.040959
# 18                   eggs & spaghetti  0.038961
# 1            chocolate & french fries  0.037962
# 9         mineral water & ground beef  0.036963
# 21            ground beef & spaghetti  0.034965
# 6   mineral water & frozen vegetables  0.034965
# 12          mineral water & olive oil  0.034965
# 17                      eggs & turkey  0.034965
# 16                        eggs & milk  0.034965
# 5           mineral water & green tea  0.033966
# 19                     eggs & burgers  0.033966
# 15           french fries & spaghetti  0.032967
# 13      frozen vegetables & spaghetti  0.031968
# 10               mineral water & soup  0.030969

# %% [markdown]
# **FP-GROWTH**
#
# Compress a large database into a compact, Frequent-Pattern tree (FP-tree) structure.
#
# Datasets are encoded using a compact structure, the FP-tree.
#
# Frequent itemsets are extracted directly from the FP-tree.
#
# ***GOAL*** To avoid candidate generation (computationally expensive)
#
# Main steps:
#
#     1. Construct the frequent pattern tree
#     2. For each frequent item: compute the projected FP-tree
#     3. Mine conditional FP-trees and grow frequent patterns
#     4. If the conditional FP-tree contains a single path: enumerate all the patterns

# %%
#Put all items of each transactions into a list
records = []
for i in range(0, len(BASKET)):
    records.append([str(BASKET.values[i, j]) for j in range(0, 20)])

# %%
#Initializing the transactionEncoder
TE = TransactionEncoder()
array = TE.fit(records).transform(records)

# %%
#Building the data frame rows are logical and columns are the items have been purchased
transf_df = pd.DataFrame(array, columns=TE.columns_)
transf_df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 996        False    False              False      False    False        False
# 997        False    False              False      False    False        False
# 998        False    False              False      False    False        False
# 999        False    False              False      False    False        False
# 1000       False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# 0     False           False      False        False  ...   False
# 1     False           False      False        False  ...   False
# 2     False           False      False        False  ...   False
# 3     False           False      False        False  ...    True
# 4     False           False      False        False  ...   False
# ...     ...             ...        ...          ...  ...     ...
# 996   False           False      False        False  ...   False
# 997   False           False      False        False  ...   False
# 998   False           False      False        False  ...   False
# 999   False           False      False        False  ...    True
# 1000  False           False      False        False  ...   False
#
#       vegetables mix  water spray  white wine  whole weat flour  \
# 0               True        False       False              True
# 1              False        False       False             False
# 2              False        False       False             False
# 3              False        False       False             False
# 4              False        False       False             False
# ...              ...          ...         ...               ...
# 996            False        False       False             False
# 997            False        False       False             False
# 998            False        False       False             False
# 999            False        False       False             False
# 1000           False        False       False             False
#
#       whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                 False             False   True        False     False
# 1                 False             False  False        False     False
# 2                 False             False  False        False     False
# 3                 False             False  False        False     False
# 4                 False              True  False        False     False
# ...                 ...               ...    ...          ...       ...
# 996               False             False  False        False     False
# 997               False             False  False        False     False
# 998               False             False  False        False     False
# 999               False             False  False        False     False
# 1000              False              True  False        False     False
#
# [1001 rows x 121 columns]

# %%
#Drop NaN
transf_df = transf_df.drop(['nan'], axis = 1)
transf_df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 996        False    False              False      False    False        False
# 997        False    False              False      False    False        False
# 998        False    False              False      False    False        False
# 999        False    False              False      False    False        False
# 1000       False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# 0     False           False      False        False  ...   False
# 1     False           False      False        False  ...   False
# 2     False           False      False        False  ...   False
# 3     False           False      False        False  ...    True
# 4     False           False      False        False  ...   False
# ...     ...             ...        ...          ...  ...     ...
# 996   False           False      False        False  ...   False
# 997   False           False      False        False  ...   False
# 998   False           False      False        False  ...   False
# 999   False           False      False        False  ...    True
# 1000  False           False      False        False  ...   False
#
#       vegetables mix  water spray  white wine  whole weat flour  \
# 0               True        False       False              True
# 1              False        False       False             False
# 2              False        False       False             False
# 3              False        False       False             False
# 4              False        False       False             False
# ...              ...          ...         ...               ...
# 996            False        False       False             False
# 997            False        False       False             False
# 998            False        False       False             False
# 999            False        False       False             False
# 1000           False        False       False             False
#
#       whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                 False             False   True        False     False
# 1                 False             False  False        False     False
# 2                 False             False  False        False     False
# 3                 False             False  False        False     False
# 4                 False              True  False        False     False
# ...                 ...               ...    ...          ...       ...
# 996               False             False  False        False     False
# 997               False             False  False        False     False
# 998               False             False  False        False     False
# 999               False             False  False        False     False
# 1000              False              True  False        False     False
#
# [1001 rows x 120 columns]

# %%
#Running the fpgrowth algorithm
res = fpgrowth(transf_df, min_support=0.05, use_colnames=True)
res
# Out:
#      support                         itemsets
# 0   0.244755                  (mineral water)
# 1   0.140859                      (green tea)
# 2   0.082917                         (shrimp)
# 3   0.082917                 (low fat yogurt)
# 4   0.075924                      (olive oil)
# 5   0.061938                (frozen smoothie)
# 6   0.999001                            (nan)
# 7   0.207792                           (eggs)
# 8   0.079920                        (burgers)
# 9   0.078921                         (turkey)
# 10  0.135864                           (milk)
# 11  0.050949               (whole wheat rice)
# 12  0.159840                   (french fries)
# 13  0.072927                           (soup)
# 14  0.185814                      (spaghetti)
# 15  0.094905              (frozen vegetables)
# 16  0.078921                        (cookies)
# 17  0.054945                    (cooking oil)
# 18  0.188811                      (chocolate)
# 19  0.066933                        (chicken)
# 20  0.083916                       (pancakes)
# 21  0.050949                  (grated cheese)
# 22  0.097902                    (ground beef)
# 23  0.082917                       (escalope)
# 24  0.068931                  (herb & pepper)
# 25  0.075924                           (cake)
# 26  0.243756             (mineral water, nan)
# 27  0.139860                 (green tea, nan)
# 28  0.081918                    (nan, shrimp)
# 29  0.081918            (low fat yogurt, nan)
# 30  0.074925                 (olive oil, nan)
# 31  0.060939           (frozen smoothie, nan)
# 32  0.207792                      (eggs, nan)
# 33  0.059940            (eggs, mineral water)
# 34  0.059940       (eggs, mineral water, nan)
# 35  0.079920                   (burgers, nan)
# 36  0.078921                    (turkey, nan)
# 37  0.135864                      (milk, nan)
# 38  0.050949          (whole wheat rice, nan)
# 39  0.159840              (french fries, nan)
# 40  0.072927                      (soup, nan)
# 41  0.185814                 (spaghetti, nan)
# 42  0.057942       (mineral water, spaghetti)
# 43  0.050949           (chocolate, spaghetti)
# 44  0.057942  (mineral water, spaghetti, nan)
# 45  0.050949      (chocolate, spaghetti, nan)
# 46  0.094905         (nan, frozen vegetables)
# 47  0.078921                   (cookies, nan)
# 48  0.054945               (cooking oil, nan)
# 49  0.188811                 (chocolate, nan)
# 50  0.058941       (chocolate, mineral water)
# 51  0.058941  (chocolate, mineral water, nan)
# 52  0.066933                   (chicken, nan)
# 53  0.083916                  (pancakes, nan)
# 54  0.050949             (grated cheese, nan)
# 55  0.097902               (ground beef, nan)
# 56  0.082917                  (escalope, nan)
# 57  0.068931             (herb & pepper, nan)
# 58  0.075924                      (cake, nan)

# %%
#Extract association rules with min confidence 0.05
res = association_rules(res, metric="confidence", min_threshold=0.05)
res
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 0   (mineral water)            (nan)            0.244755            0.999001
# 1             (nan)  (mineral water)            0.999001            0.244755
# 2       (green tea)            (nan)            0.140859            0.999001
# 3             (nan)      (green tea)            0.999001            0.140859
# 4             (nan)         (shrimp)            0.999001            0.082917
# ..              ...              ...                 ...                 ...
# 77            (nan)       (escalope)            0.999001            0.082917
# 78  (herb & pepper)            (nan)            0.068931            0.999001
# 79            (nan)  (herb & pepper)            0.999001            0.068931
# 80           (cake)            (nan)            0.075924            0.999001
# 81            (nan)           (cake)            0.999001            0.075924
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 0   0.243756    0.995918  0.996914               1.0 -0.000754    0.244755
# 1   0.243756    0.244000  0.996914               1.0 -0.000754    0.999001
# 2   0.139860    0.992908  0.993901               1.0 -0.000858    0.140859
# 3   0.139860    0.140000  0.993901               1.0 -0.000858    0.999001
# 4   0.081918    0.082000  0.988940               1.0 -0.000916    0.999001
# ..       ...         ...       ...               ...       ...         ...
# 77  0.082917    0.083000  1.001000               1.0  0.000083    1.000090
# 78  0.068931    1.000000  1.001000               1.0  0.000069         inf
# 79  0.068931    0.069000  1.001000               1.0  0.000069    1.000074
# 80  0.075924    1.000000  1.001000               1.0  0.000076         inf
# 81  0.075924    0.076000  1.001000               1.0  0.000076    1.000082
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0       -0.004082  0.243756  -3.085714    0.619959
# 1       -0.756000  0.243756  -0.001000    0.619959
# 2       -0.007092  0.139860  -6.099291    0.566454
# 3       -0.860000  0.139860  -0.001000    0.566454
# 4       -0.918000  0.081918  -0.001000    0.534976
# ..            ...       ...        ...         ...
# 77       1.000000  0.083000   0.000090    0.541500
# 78       0.001073  0.069000   1.000000    0.534500
# 79       1.000000  0.069000   0.000074    0.534500
# 80       0.001081  0.076000   1.000000    0.538000
# 81       1.000000  0.076000   0.000082    0.538000
#
# [82 rows x 14 columns]

# %%
#Sort values based on confidence
res = res.sort_values(by=['confidence'], ascending=False)
res
# Out:
#               antecedents                 consequents  antecedent support  \
# 12                 (eggs)                       (nan)            0.207792
# 16  (eggs, mineral water)                       (nan)            0.059940
# 53    (frozen vegetables)                       (nan)            0.094905
# 54              (cookies)                       (nan)            0.078921
# 56          (cooking oil)                       (nan)            0.054945
# ..                    ...                         ...                 ...
# 45                  (nan)  (mineral water, spaghetti)            0.999001
# 57                  (nan)               (cooking oil)            0.999001
# 29                  (nan)          (whole wheat rice)            0.999001
# 51                  (nan)      (chocolate, spaghetti)            0.999001
# 73                  (nan)             (grated cheese)            0.999001
#
#     consequent support   support  confidence   lift  representativity  \
# 12            0.999001  0.207792       1.000  1.001               1.0
# 16            0.999001  0.059940       1.000  1.001               1.0
# 53            0.999001  0.094905       1.000  1.001               1.0
# 54            0.999001  0.078921       1.000  1.001               1.0
# 56            0.999001  0.054945       1.000  1.001               1.0
# ..                 ...       ...         ...    ...               ...
# 45            0.057942  0.057942       0.058  1.001               1.0
# 57            0.054945  0.054945       0.055  1.001               1.0
# 29            0.050949  0.050949       0.051  1.001               1.0
# 51            0.050949  0.050949       0.051  1.001               1.0
# 73            0.050949  0.050949       0.051  1.001               1.0
#
#     leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 12  0.000208         inf       0.001261    0.208   1.000000      0.6040
# 16  0.000060         inf       0.001063    0.060   1.000000      0.5300
# 53  0.000095         inf       0.001104    0.095   1.000000      0.5475
# 54  0.000079         inf       0.001085    0.079   1.000000      0.5395
# 56  0.000055         inf       0.001057    0.055   1.000000      0.5275
# ..       ...         ...            ...      ...        ...         ...
# 45  0.000058    1.000062       1.000000    0.058   0.000062      0.5290
# 57  0.000055    1.000058       1.000000    0.055   0.000058      0.5275
# 29  0.000051    1.000054       1.000000    0.051   0.000054      0.5255
# 51  0.000051    1.000054       1.000000    0.051   0.000054      0.5255
# 73  0.000051    1.000054       1.000000    0.051   0.000054      0.5255
#
# [82 rows x 14 columns]

# %% [markdown]
# **Summary**
#
# from *mlxtend.frequent_patterns*:
#
# - apriori()
# - association_rules()
# - fpgrowth()
#
# from *pyECLAT*:
#
# - ECLAT()
